# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN & Pix2Pix in PyTorch, Jun-Yan Zhu](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix)
# * [A list of generative models](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes "fake" data to pass to the discriminator. The discriminator also sees real training data and predicts if the data it's received is real or fake.
# > * The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real, training data.
# * The discriminator is a classifier that is trained to figure out which data is real and which is fake.
#
# What ends up happening is that the generator learns to make data that is indistinguishable from real data to the discriminator.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector that the generator uses to construct its fake images. This is often called a **latent vector** and that vector space is called **latent space**. As the generator trains, it figures out how to map latent vectors to recognizable images that can fool the discriminator.
#
# If you're interested in generating only new images, you can throw out the discriminator after training. In this notebook, I'll show you how to define and train these adversarial networks in PyTorch and generate new images!

# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)

# %% [markdown]
# ### Visualize the data

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.

# %% [markdown]
# ## Discriminator
#
# The discriminator network is going to be a pretty typical linear classifier. To make this network a universal function approximator, we'll need at least one hidden layer, and these hidden layers should have one key attribute:
# > All hidden layers will have a [Leaky ReLu](https://pytorch.org/docs/stable/nn.html#torch.nn.LeakyReLU) activation function applied to their outputs.
#
# <img src='assets/gan_network.png' width=70% />
#
# #### Leaky ReLu
#
# We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# <img src='assets/leaky_relu.png' width=40% />
#
# #### Sigmoid Output
#
# We'll also take the approach of using a more numerically stable loss function on the outputs. Recall that we want the discriminator to output a value 0-1 indicating whether an image is _real or fake_.
# > We will ultimately use [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss), which combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# So, our final output layer should not have any activation function applied to it.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim*2)
        self.fc2 = nn.Linear(hidden_dim*2, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_size)
        
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        
        # pass x through all layers
        # apply leaky relu activation to all hidden layers
        x = self.fc1(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc2(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc3(x)
        x = F.leaky_relu(x, 0.2)
        #x = self.dropout(x)

        return x

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator3(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator3, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        
        # pass x through all layers
        # apply leaky relu activation to all hidden layers
        x = self.fc1(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc2(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc3(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc4(x)
        #x = F.leaky_relu(x, 0.2)
        #x = self.dropout(x)

        return x

# %% [markdown]
# ## Generator
#
# The generator network will be almost exactly the same as the discriminator network, except that we're applying a [tanh activation function](https://pytorch.org/docs/stable/nn.html#tanh) to our output layer.
#
# #### tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output, which scales the output to be between -1 and 1, instead of 0 and 1.
#
# <img src='assets/tanh_fn.png' width=40% />
#
# Recall that we also want these outputs to be comparable to the *real* input pixel values, which are read in as normalized values between 0 and 1.
# > So, we'll also have to **scale our real input images to have pixel values between -1 and 1** when we train the discriminator.
#
# I'll do this in the training loop, later on.

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*4)
        self.fc3 = nn.Linear(hidden_dim*4, output_size)
        
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        # pass x through all layers
        x = self.fc1(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc2(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc3(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        
        # final layer should have tanh applied
        x = F.tanh(x)
        
        return x

# %%
class Generator3(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator3, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        # pass x through all layers
        x = self.fc1(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc2(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc3(x)
        x = F.leaky_relu(x, 0.2)
        x = self.dropout(x)
        x = self.fc4(x)
        
        # final layer should have tanh applied
        x = F.tanh(x)
        
        return x

# %% [markdown]
# ## Model hyperparameters

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of *last* hidden layer in the discriminator
d_hidden_size = 32

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 784
# Size of *first* hidden layer in the generator
g_hidden_size = 32

# %% [markdown]
# ## Build complete network
#
# Now we're instantiating the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
# instantiate discriminator and generator
#D = Discriminator(input_size, d_hidden_size, d_output_size)
#G = Generator(z_size, g_hidden_size, g_output_size)
D = Discriminator3(input_size, d_hidden_size, d_output_size)
G = Generator3(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator3(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
#
# Generator3(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The losses will by binary cross entropy loss with logits, which we can get with [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss). This combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# For the real images, we want `D(real_images) = 1`. That is, we want the discriminator to classify the the real images with a label = 1, indicating that these are real. To help the discriminator generalize better, the labels are **reduced a bit from 1.0 to 0.9**. For this, we'll use the parameter `smooth`; if True, then we should smooth our labels. In PyTorch, this looks like `labels = torch.ones(size) * 0.9`
#
# The discriminator loss for the fake data is similar. We want `D(fake_images) = 0`, where the fake images are the _generator output_, `fake_images = G(z)`.
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get `D(fake_images) = 1`. In this case, the labels are **flipped** to represent that the generator is trying to fool the discriminator into thinking that the images it generates (fakes) are real!

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # compare logits to real labels
    # smooth labels if smooth=True
    if smooth == True:
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size)
        
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    # compare logits to fake labels
    labels = torch.zeros(batch_size)
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So, we'll define two separate Adam optimizers.

# %%
import torch.optim as optim

# learning rate for optimizers
lr = 0.002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. We'll use our functions `real_loss` and `fake_loss` to help us calculate the discriminator losses in all of the following cases.
#
# ### Discriminator training
# 1. Compute the discriminator loss on real, training images
# 2. Generate fake images
# 3. Compute the discriminator loss on fake, generated images
# 4. Add up real and fake loss
# 5. Perform backpropagation + an optimization step to update the discriminator's weights
#
# ### Generator training
# 1. Generate fake images
# 2. Compute the discriminator loss on fake images, using **flipped** labels!
# 3. Perform backpropagation + an optimization step to update the generator's weights
#
# #### Saving Samples
#
# As we train, we'll also print out some loss statistics and save some generated "fake" samples.

# %%
import pickle as pkl

# training hyperparams
num_epochs = 100

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1)
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
                
        d_optimizer.zero_grad()
        # 1. Train with real images

        # Compute the discriminator losses on real images
        # use smoothed labels
        D_real = D(real_images)
        dr_loss = real_loss(D_real, smooth=True)
        
        # 2. Train with fake images
        
        # Generate fake images
        #G.eval()
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images
        D_fake = D(fake_images)
        df_loss = fake_loss(D_fake)
        
        # add up real and fake losses and perform backprop
        d_loss = dr_loss + df_loss
        d_loss.backward()
        d_optimizer.step()        
        
        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================

        # 1. Train with fake images and flipped labels
        g_optimizer.zero_grad()
        
        # Generate fake images
        #G.eval()
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        #G.train()
        #g_optimizer.zero_grad()
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        g_loss = 1.0 - fake_loss(D(fake_images))
        #D_fake = D(fake_images)
        #g_loss = real_loss(D_fake)
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()        

        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples_3layer.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch [    1/  100] | d_loss: 1.3824 | g_loss: 0.3659
# Epoch [    1/  100] | d_loss: 0.3357 | g_loss: 0.9870
# Epoch [    1/  100] | d_loss: 0.4382 | g_loss: 0.9826
# Epoch [    2/  100] | d_loss: 0.6967 | g_loss: 0.6050
# Epoch [    2/  100] | d_loss: 0.4630 | g_loss: 0.9921
# Epoch [    2/  100] | d_loss: 0.9408 | g_loss: 0.6678
# Epoch [    3/  100] | d_loss: 1.2441 | g_loss: 0.5871
# Epoch [    3/  100] | d_loss: 0.6913 | g_loss: 0.6664
# Epoch [    3/  100] | d_loss: 1.1213 | g_loss: 0.6923
# Epoch [    4/  100] | d_loss: 1.2786 | g_loss: 0.4020
# Epoch [    4/  100] | d_loss: 1.3794 | g_loss: 0.2417
# Epoch [    4/  100] | d_loss: 1.3950 | g_loss: 0.6526
# Epoch [    5/  100] | d_loss: 1.1464 | g_loss: 0.4588
# Epoch [    5/  100] | d_loss: 1.2513 | g_loss: 0.6793
# Epoch [    5/  100] | d_loss: 1.3440 | g_loss: 0.4528
# Epoch [    6/  100] | d_loss: 1.2689 | g_loss: 0.4511
# Epoch [    6/  100] | d_loss: 1.2774 | g_loss: 0.4432
# Epoch [    6/  100] | d_loss: 1.1350 | g_loss: 0.3643
# Epoch [    7/  100] | d_loss: 1.1595 | g_loss: 0.4323
# Epoch [    7/  100] | d_loss: 0.9473 | g_loss: 0.7127
# Epoch [    7/  100] | d_loss: 1.0129 | g_loss: 0.6700
# Epoch [    8/  100] | d_loss: 1.2261 | g_loss: 0.5170
# Epoch [    8/  100] | d_loss: 1.2920 | g_loss: 0.5088
# Epoch [    8/  100] | d_loss: 1.1188 | g_loss: 0.6330
# Epoch [    9/  100] | d_loss: 1.2774 | g_loss: 0.5950
# Epoch [    9/  100] | d_loss: 1.4119 | g_loss: 0.2438
# Epoch [    9/  100] | d_loss: 1.1573 | g_loss: 0.5973
# Epoch [   10/  100] | d_loss: 1.2969 | g_loss: 0.4616
# Epoch [   10/  100] | d_loss: 1.2327 | g_loss: 0.3363
# Epoch [   10/  100] | d_loss: 1.2118 | g_loss: 0.5161
# Epoch [   11/  100] | d_loss: 1.1524 | g_loss: 0.8107
# Epoch [   11/  100] | d_loss: 1.3653 | g_loss: 0.3849
# Epoch [   11/  100] | d_loss: 1.3353 | g_loss: 0.3274
# Epoch [   12/  100] | d_loss: 1.4049 | g_loss: 0.4409
# Epoch [   12/  100] | d_loss: 1.2798 | g_loss: 0.4175
# Epoch [   12/  100] | d_loss: 1.4732 | g_loss: 0.2467
# Epoch [   13/  100] | d_loss: 1.4102 | g_loss: 0.2284
# Epoch [   13/  100] | d_loss: 1.2551 | g_loss: 0.4595
# Epoch [   13/  100] | d_loss: 0.9379 | g_loss: 0.7257
# Epoch [   14/  100] | d_loss: 0.9642 | g_loss: 0.6634
# Epoch [   14/  100] | d_loss: 1.4399 | g_loss: 0.4041
# Epoch [   14/  100] | d_loss: 1.4465 | g_loss: 0.2871
# Epoch [   15/  100] | d_loss: 1.2219 | g_loss: 0.5712
# Epoch [   15/  100] | d_loss: 1.2588 | g_loss: 0.5128
# Epoch [   15/  100] | d_loss: 0.9849 | g_loss: 0.6222
# Epoch [   16/  100] | d_loss: 1.2260 | g_loss: 0.4503
# Epoch [   16/  100] | d_loss: 1.2831 | g_loss: 0.3038
# Epoch [   16/  100] | d_loss: 1.1433 | g_loss: 0.4396
# Epoch [   17/  100] | d_loss: 1.4101 | g_loss: 0.2600
# Epoch [   17/  100] | d_loss: 1.3065 | g_loss: 0.4060
# Epoch [   17/  100] | d_loss: 1.3637 | g_loss: 0.5179
# Epoch [   18/  100] | d_loss: 1.4807 | g_loss: 0.4033
# Epoch [   18/  100] | d_loss: 1.3587 | g_loss: 0.5389
# Epoch [   18/  100] | d_loss: 1.0674 | g_loss: 0.4923
# Epoch [   19/  100] | d_loss: 0.9931 | g_loss: 0.7361
# Epoch [   19/  100] | d_loss: 1.3152 | g_loss: 0.5350
# Epoch [   19/  100] | d_loss: 0.9246 | g_loss: 0.6658
# Epoch [   20/  100] | d_loss: 1.3197 | g_loss: 0.5595
# Epoch [   20/  100] | d_loss: 1.2459 | g_loss: 0.5218
# Epoch [   20/  100] | d_loss: 1.4600 | g_loss: 0.1733
# Epoch [   21/  100] | d_loss: 1.4026 | g_loss: 0.3793
# Epoch [   21/  100] | d_loss: 1.4467 | g_loss: 0.4465
# Epoch [   21/  100] | d_loss: 0.8921 | g_loss: 0.7253
# Epoch [   22/  100] | d_loss: 1.1949 | g_loss: 0.5440
# Epoch [   22/  100] | d_loss: 1.2622 | g_loss: 0.4963
# Epoch [   22/  100] | d_loss: 1.4457 | g_loss: 0.5153
# Epoch [   23/  100] | d_loss: 1.3998 | g_loss: 0.4029
# Epoch [   23/  100] | d_loss: 1.3509 | g_loss: 0.3283
# Epoch [   23/  100] | d_loss: 1.2452 | g_loss: 0.5679
# Epoch [   24/  100] | d_loss: 1.6353 | g_loss: 0.3270
# Epoch [   24/  100] | d_loss: 1.0586 | g_loss: 0.6403
# Epoch [   24/  100] | d_loss: 1.4387 | g_loss: 0.1253
# Epoch [   25/  100] | d_loss: 1.4743 | g_loss: 0.2548
# Epoch [   25/  100] | d_loss: 1.0578 | g_loss: 0.7170
# Epoch [   25/  100] | d_loss: 1.1635 | g_loss: 0.6036
# Epoch [   26/  100] | d_loss: 1.3288 | g_loss: 0.5665
# Epoch [   26/  100] | d_loss: 1.2844 | g_loss: 0.5102
# Epoch [   26/  100] | d_loss: 1.3116 | g_loss: 0.4563
# Epoch [   27/  100] | d_loss: 1.0805 | g_loss: 0.6794
# Epoch [   27/  100] | d_loss: 1.3430 | g_loss: 0.4788
# Epoch [   27/  100] | d_loss: 1.2590 | g_loss: 0.7130
# Epoch [   28/  100] | d_loss: 1.3115 | g_loss: 0.4490
# Epoch [   28/  100] | d_loss: 1.4124 | g_loss: 0.2724
# Epoch [   28/  100] | d_loss: 1.0975 | g_loss: 0.4591
# Epoch [   29/  100] | d_loss: 1.3536 | g_loss: 0.3719
# Epoch [   29/  100] | d_loss: 1.5147 | g_loss: 0.3112
# Epoch [   29/  100] | d_loss: 1.2356 | g_loss: 0.5203
# Epoch [   30/  100] | d_loss: 1.3242 | g_loss: 0.4479
# Epoch [   30/  100] | d_loss: 1.1126 | g_loss: 0.5556
# Epoch [   30/  100] | d_loss: 1.2455 | g_loss: 0.4640
# Epoch [   31/  100] | d_loss: 1.4890 | g_loss: 0.3324
# Epoch [   31/  100] | d_loss: 1.3909 | g_loss: 0.4521
# Epoch [   31/  100] | d_loss: 1.3364 | g_loss: 0.2792
# Epoch [   32/  100] | d_loss: 1.3138 | g_loss: 0.4777
# Epoch [   32/  100] | d_loss: 1.1692 | g_loss: 0.6425
# Epoch [   32/  100] | d_loss: 1.1922 | g_loss: 0.6011
# Epoch [   33/  100] | d_loss: 1.0928 | g_loss: 0.5979
# Epoch [   33/  100] | d_loss: 1.3935 | g_loss: 0.3573
# Epoch [   33/  100] | d_loss: 1.2621 | g_loss: 0.3541
# Epoch [   34/  100] | d_loss: 1.4139 | g_loss: 0.3864
# Epoch [   34/  100] | d_loss: 1.3868 | g_loss: 0.4443
# Epoch [   34/  100] | d_loss: 1.3410 | g_loss: 0.5019
# Epoch [   35/  100] | d_loss: 1.2691 | g_loss: 0.4226
# Epoch [   35/  100] | d_loss: 1.3609 | g_loss: 0.3118
# Epoch [   35/  100] | d_loss: 1.4013 | g_loss: 0.3197
# Epoch [   36/  100] | d_loss: 1.3575 | g_loss: 0.4532
# Epoch [   36/  100] | d_loss: 1.3184 | g_loss: 0.5310
# Epoch [   36/  100] | d_loss: 1.4857 | g_loss: 0.2912
# Epoch [   37/  100] | d_loss: 1.2680 | g_loss: 0.5289
# Epoch [   37/  100] | d_loss: 1.3236 | g_loss: 0.3235
# Epoch [   37/  100] | d_loss: 1.3894 | g_loss: 0.4152
# Epoch [   38/  100] | d_loss: 1.1257 | g_loss: 0.7118
# Epoch [   38/  100] | d_loss: 1.1829 | g_loss: 0.5782
# Epoch [   38/  100] | d_loss: 1.2933 | g_loss: 0.3563
# Epoch [   39/  100] | d_loss: 1.2295 | g_loss: 0.6519
# Epoch [   39/  100] | d_loss: 1.0921 | g_loss: 0.5600
# Epoch [   39/  100] | d_loss: 1.2152 | g_loss: 0.5188
# Epoch [   40/  100] | d_loss: 1.5244 | g_loss: 0.6070
# Epoch [   40/  100] | d_loss: 1.3480 | g_loss: 0.3968
# Epoch [   40/  100] | d_loss: 1.3200 | g_loss: 0.5706
# Epoch [   41/  100] | d_loss: 1.2163 | g_loss: 0.4501
# Epoch [   41/  100] | d_loss: 1.1823 | g_loss: 0.6038
# Epoch [   41/  100] | d_loss: 1.1794 | g_loss: 0.5180
# Epoch [   42/  100] | d_loss: 1.1227 | g_loss: 0.7479
# Epoch [   42/  100] | d_loss: 1.3405 | g_loss: 0.3368
# Epoch [   42/  100] | d_loss: 1.3426 | g_loss: 0.3972
# Epoch [   43/  100] | d_loss: 1.4215 | g_loss: 0.2301
# Epoch [   43/  100] | d_loss: 1.4031 | g_loss: 0.4080
# Epoch [   43/  100] | d_loss: 1.2262 | g_loss: 0.6933
# Epoch [   44/  100] | d_loss: 1.1433 | g_loss: 0.6420
# Epoch [   44/  100] | d_loss: 1.4068 | g_loss: 0.5091
# Epoch [   44/  100] | d_loss: 1.3738 | g_loss: 0.3222
# Epoch [   45/  100] | d_loss: 1.3629 | g_loss: 0.4454
# Epoch [   45/  100] | d_loss: 1.2120 | g_loss: 0.5209
# Epoch [   45/  100] | d_loss: 1.5345 | g_loss: 0.0808
# Epoch [   46/  100] | d_loss: 1.3871 | g_loss: 0.5617
# Epoch [   46/  100] | d_loss: 0.9611 | g_loss: 0.5754
# Epoch [   46/  100] | d_loss: 1.4032 | g_loss: 0.4358
# Epoch [   47/  100] | d_loss: 1.2877 | g_loss: 0.3694
# Epoch [   47/  100] | d_loss: 1.4097 | g_loss: 0.3872
# Epoch [   47/  100] | d_loss: 1.3164 | g_loss: 0.4936
# Epoch [   48/  100] | d_loss: 1.2662 | g_loss: 0.3090
# Epoch [   48/  100] | d_loss: 1.4360 | g_loss: 0.1760
# Epoch [   48/  100] | d_loss: 1.4620 | g_loss: 0.2688
# Epoch [   49/  100] | d_loss: 1.1235 | g_loss: 0.6220
# Epoch [   49/  100] | d_loss: 1.4083 | g_loss: 0.3651
# Epoch [   49/  100] | d_loss: 1.4037 | g_loss: 0.4944
# Epoch [   50/  100] | d_loss: 1.2628 | g_loss: 0.5279
# Epoch [   50/  100] | d_loss: 1.3622 | g_loss: 0.4317
# Epoch [   50/  100] | d_loss: 1.4339 | g_loss: 0.4898
# Epoch [   51/  100] | d_loss: 1.5275 | g_loss: 0.5238
# Epoch [   51/  100] | d_loss: 1.0363 | g_loss: 0.4880
# Epoch [   51/  100] | d_loss: 1.3830 | g_loss: 0.4549
# Epoch [   52/  100] | d_loss: 1.2483 | g_loss: 0.5064
# Epoch [   52/  100] | d_loss: 1.3471 | g_loss: 0.5072
# Epoch [   52/  100] | d_loss: 1.2326 | g_loss: 0.3389
# Epoch [   53/  100] | d_loss: 1.4258 | g_loss: 0.4791
# Epoch [   53/  100] | d_loss: 1.2280 | g_loss: 0.4176
# Epoch [   53/  100] | d_loss: 1.5846 | g_loss: 0.3171
# Epoch [   54/  100] | d_loss: 1.3296 | g_loss: 0.4944
# Epoch [   54/  100] | d_loss: 1.4405 | g_loss: 0.4364
# Epoch [   54/  100] | d_loss: 1.1448 | g_loss: 0.5201
# Epoch [   55/  100] | d_loss: 1.2742 | g_loss: 0.6211
# Epoch [   55/  100] | d_loss: 1.0472 | g_loss: 0.7913
# Epoch [   55/  100] | d_loss: 1.3133 | g_loss: 0.4398
# Epoch [   56/  100] | d_loss: 1.3361 | g_loss: 0.5720
# Epoch [   56/  100] | d_loss: 1.1687 | g_loss: 0.6740
# Epoch [   56/  100] | d_loss: 1.3518 | g_loss: 0.4356
# Epoch [   57/  100] | d_loss: 1.6284 | g_loss: 0.3788
# Epoch [   57/  100] | d_loss: 1.2701 | g_loss: 0.5605
# Epoch [   57/  100] | d_loss: 1.3644 | g_loss: 0.5952
# Epoch [   58/  100] | d_loss: 1.2037 | g_loss: 0.5389
# Epoch [   58/  100] | d_loss: 1.4345 | g_loss: 0.3036
# Epoch [   58/  100] | d_loss: 1.3501 | g_loss: 0.3998
# Epoch [   59/  100] | d_loss: 1.2663 | g_loss: 0.6899
# Epoch [   59/  100] | d_loss: 1.3603 | g_loss: 0.3603
# Epoch [   59/  100] | d_loss: 1.0847 | g_loss: 0.6032
# Epoch [   60/  100] | d_loss: 1.3722 | g_loss: 0.2649
# Epoch [   60/  100] | d_loss: 1.4914 | g_loss: 0.4270
# Epoch [   60/  100] | d_loss: 1.3205 | g_loss: 0.4448
# Epoch [   61/  100] | d_loss: 1.2673 | g_loss: 0.6504
# Epoch [   61/  100] | d_loss: 1.2656 | g_loss: 0.4905
# Epoch [   61/  100] | d_loss: 1.2715 | g_loss: 0.5065
# Epoch [   62/  100] | d_loss: 1.2302 | g_loss: 0.5156
# Epoch [   62/  100] | d_loss: 1.5289 | g_loss: 0.4151
# Epoch [   62/  100] | d_loss: 1.2392 | g_loss: 0.5175
# Epoch [   63/  100] | d_loss: 1.3410 | g_loss: 0.3561
# Epoch [   63/  100] | d_loss: 1.1427 | g_loss: 0.5505
# Epoch [   63/  100] | d_loss: 1.4555 | g_loss: 0.3698
# Epoch [   64/  100] | d_loss: 1.3576 | g_loss: 0.4671
# Epoch [   64/  100] | d_loss: 1.2419 | g_loss: 0.4469
# Epoch [   64/  100] | d_loss: 1.3881 | g_loss: 0.4361
# Epoch [   65/  100] | d_loss: 1.2890 | g_loss: 0.2553
# Epoch [   65/  100] | d_loss: 1.3857 | g_loss: 0.3037
# Epoch [   65/  100] | d_loss: 1.1857 | g_loss: 0.6198
# Epoch [   66/  100] | d_loss: 1.3660 | g_loss: 0.3838
# Epoch [   66/  100] | d_loss: 1.3681 | g_loss: 0.4739
# Epoch [   66/  100] | d_loss: 1.2372 | g_loss: 0.6457
# Epoch [   67/  100] | d_loss: 1.2955 | g_loss: 0.5502
# Epoch [   67/  100] | d_loss: 1.3985 | g_loss: 0.3521
# Epoch [   67/  100] | d_loss: 1.3394 | g_loss: 0.5236
# Epoch [   68/  100] | d_loss: 1.3586 | g_loss: 0.2459
# Epoch [   68/  100] | d_loss: 1.2797 | g_loss: 0.5940
# Epoch [   68/  100] | d_loss: 1.4267 | g_loss: 0.3512
# Epoch [   69/  100] | d_loss: 1.3410 | g_loss: 0.5052
# Epoch [   69/  100] | d_loss: 1.3518 | g_loss: 0.4496
# Epoch [   69/  100] | d_loss: 1.1186 | g_loss: 0.6129
# Epoch [   70/  100] | d_loss: 1.3063 | g_loss: 0.5071
# Epoch [   70/  100] | d_loss: 1.0739 | g_loss: 0.5434
# Epoch [   70/  100] | d_loss: 1.3587 | g_loss: 0.4882
# Epoch [   71/  100] | d_loss: 1.3638 | g_loss: 0.5433
# Epoch [   71/  100] | d_loss: 1.4169 | g_loss: 0.2634
# Epoch [   71/  100] | d_loss: 1.2068 | g_loss: 0.5771
# Epoch [   72/  100] | d_loss: 1.2544 | g_loss: 0.6656
# Epoch [   72/  100] | d_loss: 1.1772 | g_loss: 0.5410
# Epoch [   72/  100] | d_loss: 1.2685 | g_loss: 0.6836
# Epoch [   73/  100] | d_loss: 1.2568 | g_loss: 0.4299
# Epoch [   73/  100] | d_loss: 1.0994 | g_loss: 0.5050
# Epoch [   73/  100] | d_loss: 1.1102 | g_loss: 0.6692
# Epoch [   74/  100] | d_loss: 1.3094 | g_loss: 0.5251
# Epoch [   74/  100] | d_loss: 1.4663 | g_loss: 0.2624
# Epoch [   74/  100] | d_loss: 1.1943 | g_loss: 0.5503
# Epoch [   75/  100] | d_loss: 1.1397 | g_loss: 0.6236
# Epoch [   75/  100] | d_loss: 1.2065 | g_loss: 0.5917
# Epoch [   75/  100] | d_loss: 1.4399 | g_loss: 0.2601
# Epoch [   76/  100] | d_loss: 1.3541 | g_loss: 0.6795
# Epoch [   76/  100] | d_loss: 1.1864 | g_loss: 0.4896
# Epoch [   76/  100] | d_loss: 1.2413 | g_loss: 0.5348
# Epoch [   77/  100] | d_loss: 1.1846 | g_loss: 0.7103
# Epoch [   77/  100] | d_loss: 1.1652 | g_loss: 0.4210
# Epoch [   77/  100] | d_loss: 1.2999 | g_loss: 0.5353
# Epoch [   78/  100] | d_loss: 1.2095 | g_loss: 0.5483
# Epoch [   78/  100] | d_loss: 1.2751 | g_loss: 0.4662
# Epoch [   78/  100] | d_loss: 1.1971 | g_loss: 0.6448
# Epoch [   79/  100] | d_loss: 1.2872 | g_loss: 0.5661
# Epoch [   79/  100] | d_loss: 1.2944 | g_loss: 0.4603
# Epoch [   79/  100] | d_loss: 1.4348 | g_loss: 0.3070
# Epoch [   80/  100] | d_loss: 1.3349 | g_loss: 0.5296
# Epoch [   80/  100] | d_loss: 1.4255 | g_loss: 0.5164
# Epoch [   80/  100] | d_loss: 1.1100 | g_loss: 0.6256
# Epoch [   81/  100] | d_loss: 1.3782 | g_loss: 0.4664
# Epoch [   81/  100] | d_loss: 1.4201 | g_loss: 0.2367
# Epoch [   81/  100] | d_loss: 1.0804 | g_loss: 0.6360
# Epoch [   82/  100] | d_loss: 1.1781 | g_loss: 0.4821
# Epoch [   82/  100] | d_loss: 1.3907 | g_loss: 0.4147
# Epoch [   82/  100] | d_loss: 1.4033 | g_loss: 0.3556
# Epoch [   83/  100] | d_loss: 1.3405 | g_loss: 0.2265
# Epoch [   83/  100] | d_loss: 1.3369 | g_loss: 0.5056
# Epoch [   83/  100] | d_loss: 1.4170 | g_loss: 0.3265
# Epoch [   84/  100] | d_loss: 1.3816 | g_loss: 0.3936
# Epoch [   84/  100] | d_loss: 1.3718 | g_loss: 0.4455
# Epoch [   84/  100] | d_loss: 1.2183 | g_loss: 0.4379
# Epoch [   85/  100] | d_loss: 1.2288 | g_loss: 0.5126
# Epoch [   85/  100] | d_loss: 1.3610 | g_loss: 0.3407
# Epoch [   85/  100] | d_loss: 1.2328 | g_loss: 0.3951
# Epoch [   86/  100] | d_loss: 1.2042 | g_loss: 0.5523
# Epoch [   86/  100] | d_loss: 1.3584 | g_loss: 0.3707
# Epoch [   86/  100] | d_loss: 1.2748 | g_loss: 0.4515
# Epoch [   87/  100] | d_loss: 1.3592 | g_loss: 0.3837
# Epoch [   87/  100] | d_loss: 1.3753 | g_loss: 0.4306
# Epoch [   87/  100] | d_loss: 1.3178 | g_loss: 0.4754
# Epoch [   88/  100] | d_loss: 1.3117 | g_loss: 0.5605
# Epoch [   88/  100] | d_loss: 1.2544 | g_loss: 0.4464
# Epoch [   88/  100] | d_loss: 1.3755 | g_loss: 0.5065
# Epoch [   89/  100] | d_loss: 1.3709 | g_loss: 0.3366
# Epoch [   89/  100] | d_loss: 1.2892 | g_loss: 0.5205
# Epoch [   89/  100] | d_loss: 1.3728 | g_loss: 0.4980
# Epoch [   90/  100] | d_loss: 1.0330 | g_loss: 0.4998
# Epoch [   90/  100] | d_loss: 1.2662 | g_loss: 0.4558
# Epoch [   90/  100] | d_loss: 1.4290 | g_loss: 0.3329
# Epoch [   91/  100] | d_loss: 1.2692 | g_loss: 0.6752
# Epoch [   91/  100] | d_loss: 1.2831 | g_loss: 0.4763
# Epoch [   91/  100] | d_loss: 1.2335 | g_loss: 0.5796
# Epoch [   92/  100] | d_loss: 1.3746 | g_loss: 0.6106
# Epoch [   92/  100] | d_loss: 1.2108 | g_loss: 0.5726
# Epoch [   92/  100] | d_loss: 1.2695 | g_loss: 0.4908
# Epoch [   93/  100] | d_loss: 1.3539 | g_loss: 0.3391
# Epoch [   93/  100] | d_loss: 1.3990 | g_loss: 0.4084
# Epoch [   93/  100] | d_loss: 1.4096 | g_loss: 0.3936
# Epoch [   94/  100] | d_loss: 1.1619 | g_loss: 0.2602
# Epoch [   94/  100] | d_loss: 1.2746 | g_loss: 0.4488
# Epoch [   94/  100] | d_loss: 1.5346 | g_loss: 0.3170
# Epoch [   95/  100] | d_loss: 1.3301 | g_loss: 0.5342
# Epoch [   95/  100] | d_loss: 1.3892 | g_loss: 0.3283
# Epoch [   95/  100] | d_loss: 1.3957 | g_loss: 0.3825
# Epoch [   96/  100] | d_loss: 1.3505 | g_loss: 0.5216
# Epoch [   96/  100] | d_loss: 1.2258 | g_loss: 0.6424
# Epoch [   96/  100] | d_loss: 1.3577 | g_loss: 0.4404
# Epoch [   97/  100] | d_loss: 1.4563 | g_loss: 0.2349
# Epoch [   97/  100] | d_loss: 1.2824 | g_loss: 0.4605
# Epoch [   97/  100] | d_loss: 1.3344 | g_loss: 0.4300
# Epoch [   98/  100] | d_loss: 1.4341 | g_loss: 0.3349
# Epoch [   98/  100] | d_loss: 1.2439 | g_loss: 0.5849
# Epoch [   98/  100] | d_loss: 1.4320 | g_loss: 0.3786
# Epoch [   99/  100] | d_loss: 1.2503 | g_loss: 0.5118
# Epoch [   99/  100] | d_loss: 1.3393 | g_loss: 0.4532
# Epoch [   99/  100] | d_loss: 1.3892 | g_loss: 0.3722
# Epoch [  100/  100] | d_loss: 1.0832 | g_loss: 0.5064
# Epoch [  100/  100] | d_loss: 1.6349 | g_loss: 0.4641
# Epoch [  100/  100] | d_loss: 1.2345 | g_loss: 0.5963

# %% [markdown]
# ## Training loss
#
# Here we'll plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at the images we saved during training.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples_3layer.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 1, 7, 3, 2. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs.

# %%
rows = 10 # split epochs into 10, so 100/10 = every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise like 1s and 9s.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. **We just need to pass in a new latent vector $z$ and we'll get new samples**!

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
# Out:
# /home/keiyonezawa/anaconda3/envs/pyt-udacity/lib/python3.9/site-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
